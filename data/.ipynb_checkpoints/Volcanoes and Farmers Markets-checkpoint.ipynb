# %% [markdown]
# ## Holocene Period Volcanoes Data

# %% [markdown]
#    1. Import and scrub holocene period volcano data

# %%
#import modules 
import pandas as pd
import numpy as np 
import folium 
import requests
import matplotlib.cm as cm
import matplotlib.colors as colors


from geopy.geocoders import Nominatim 
from pandas.io.json import json_normalize
from sklearn.cluster import KMeans

# %%
#import eruption data
df = pd.read_csv('database.csv')

# %%
#select only US data
us_eruptions = df.loc[df['Country'] == 'United States']
us_eruptions.head()
# Out:
#      Number         Name        Country                   Region  \
# 271  244000    Vailulu'u  United States      New Zealand to Fiji
# 272  244001         Ta'u  United States      New Zealand to Fiji
# 273  244010  Ofu-Olosega  United States      New Zealand to Fiji
# 274  244020      Tutuila  United States      New Zealand to Fiji
# 661  284133      Fukujin  United States  Japan, Taiwan, Marianas
#
#              Type  Activity Evidence Last Known Eruption  Latitude  Longitude  \
# 271     Submarine  Eruption Observed             2003 CE   -14.215   -169.058
# 272        Shield  Evidence Credible             Unknown   -14.230   -169.454
# 273     Shield(s)  Eruption Observed             1866 CE   -14.175   -169.618
# 274  Tuff cone(s)  Evidence Credible             Unknown   -14.295   -170.700
# 661     Submarine  Eruption Observed             1974 CE    21.930    143.470
#
#      Elevation (Meters)            Dominant Rock Type  \
# 271                -592         Basalt / Picro-Basalt
# 272                 931         Basalt / Picro-Basalt
# 273                 639         Basalt / Picro-Basalt
# 274                 653         Basalt / Picro-Basalt
# 661                -217  Andesite / Basaltic Andesite
#
#                               Tectonic Setting
# 271  Subduction Zone / Oceanic Crust (< 15 km)
# 272  Subduction Zone / Oceanic Crust (< 15 km)
# 273  Subduction Zone / Oceanic Crust (< 15 km)
# 274  Subduction Zone / Oceanic Crust (< 15 km)
# 661  Subduction Zone / Crust Thickness Unknown

# %%
#assign country, lat and long to new dataframe 
eruption_location = us_eruptions.drop(columns = ['Number', 'Name', 'Type', 'Activity Evidence','Last Known Eruption','Elevation (Meters)',
       'Dominant Rock Type', 'Tectonic Setting'])
pd.DataFrame(eruption_location)
eruption_location.reset_index('Country', inplace=True)
eruption_location.head()
# Out:
#                                 Region  Latitude  Longitude
# Country
# United States      New Zealand to Fiji   -14.215   -169.058
# United States      New Zealand to Fiji   -14.230   -169.454
# United States      New Zealand to Fiji   -14.175   -169.618
# United States      New Zealand to Fiji   -14.295   -170.700
# United States  Japan, Taiwan, Marianas    21.930    143.470

# %%
#Find the central lat/lon for the US

address = 'United States'
geolocator = Nominatim(user_agent = 'ny_explorer')
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of the United States are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of the United States are 39.7837304, -100.4458825.

# %% [markdown]
# #### A map of US volcanic eruptions during the holocene period.

# %%
#Create map of volcanic eruptions
volcano_map = folium.Map(location =[latitude, longitude], zoom_start = 4)

for lat, lng, country in zip(eruption_location['Latitude'], eruption_location['Longitude'], 
                             eruption_location['Country']):
    
    label='{}'.format(country)
    label=folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='brown',
        fill=True,
        fill_color='pink',
        fill_opacity=0.7,
        parse_html=False).add_to(volcano_map)  
    
volcano_map
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-141-4c8bf4535308> in <module>
#       3
#       4 for lat, lng, country in zip(eruption_location['Latitude'], eruption_location['Longitude'],
# ----> 5                              eruption_location['Country']):
#       6
#       7     label='{}'.format(country)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Country'

# %% [markdown]
# #### Now that we have our volcano data cleaned and mapped, it's time to begin importing farmers market data.

# %%
#Begin by importing foursquare api. 
#This will enable us to gather farmers market data from around the 
#United States. 

#API credentials
CLIENT_ID = "JMOWNXMATF51YXVSMAKIWXT3PKINLTRXVN0Q3HCFUZNLVGA0"
CLIENT_SECRET = "BWUQXFHVPMMK4VFDOSZZ1U5K0HWKBCUAYX2AP1LQ2VKQ2UEU"
VERSION = '20200401'

# %%
eruption_location.loc[0, 'Country']
# Out:
# 'United States'

# %%
eruption_lat = eruption_location.loc[0, 'Latitude'] #eruption latitude, assign to variable for 4square iteration
eruption_long = eruption_location.loc[0, 'Longitude'] #longitude ~~

eruption_country = eruption_location.loc[0, 'Country']

print('Latitude and longitude values of {} are {}, {}.'.format(eruption_country, 
                                                               eruption_lat, 
                                                               eruption_long))
# Out:
# Latitude and longitude values of United States are -14.215, -169.058.

# %% [markdown]
# ## Time to get our farmers markets

# %%
#api call
LIMIT = 25 # limit of number of venues returned by Foursquare API
radius = 500 # define radius 
#query = "farmers markets" #add query parameter
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            eruption_lat, 
            eruption_long, 
            radius, 
            LIMIT)

# %%
results = requests.get(url).json()

# %%
#function to grab venues near volcano eruptions
def get_venues(lat,lng):
    
    #set variables
    radius=1000
    LIMIT=100
    CLIENT_ID = ['CLIENT_ID'] # your Foursquare ID
    CLIENT_SECRET = ['CLIENT_SECRET']
    query = "Farmers20%Market"# your Foursquare Secret
    VERSION = '20200401' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll=40.7,-74&query={}&v={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            lat, 
            lng, 
            query,
            VERSION,
            radius, 
            LIMIT)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results["response"]['groups'][0]['items']
    venue_details=[]
    for row in venue_data:
        try:
            venue_id=row['venue']['id']
            venue_name=row['venue']['name']
            venue_category=row['venue']['categories'][0]['name']
            venue_details.append([venue_id,venue_name,venue_category])
        except KeyError:
            pass
        
    column_names=['ID','Name','Category']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
def get_venue_details(venue_id):
        
    CLIENT_ID = ['CLIENT_ID'] # your Foursquare ID
    CLIENT_SECRET = ['CLIENT_SECRET'] # your Foursquare Secret
    VERSION = '20200401' # Foursquare API version
    
    #url to fetch data from foursquare api
    url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
            venue_id,
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION)
    
    # get all the data
    results = requests.get(url).json()
    venue_data=results['response']['venue']
    venue_details=[]
    try:
        venue_id=venue_data['id']
        venue_name=venue_data['name']
        venue_likes=venue_data['likes']['count']
        venue_rating=venue_data['rating']
        venue_tips=venue_data['tips']['count']
        venue_details.append([venue_id,venue_name,venue_likes,venue_rating,venue_tips])
    except KeyError:
        pass
        
    column_names=['ID','Name','Likes','Rating','Tips']
    df = pd.DataFrame(venue_details,columns=column_names)
    return df

# %%
def get_eruption_data():
    data = eruption_location
    return data

# %%
eruption_data.shape
# Out:
# (173, 5)

# %%
volc_venues = getNearbyVenues(names=eruption_data['Country'],
                                   latitudes=eruption_data['Latitude'],
                                   longitudes=eruption_data['Longitude']
                                  )
print(volc_venues)
# Out:
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
# United States
#      Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0   United States                 46.853                -121.760
# 1   United States                 46.853                -121.760
# 2   United States                 46.853                -121.760
# 3   United States                 45.880                -122.080
# 4   United States                 45.374                -121.695
# 5   United States                 45.374                -121.695
# 6   United States                 43.979                -121.688
# 7   United States                 43.241                -122.108
# 8   United States                 42.930                -122.120
# 9   United States                 41.409                -122.193
# 10  United States                 41.409                -122.193
# 11  United States                 41.409                -122.193
# 12  United States                 40.492                -121.508
# 13  United States                 37.631                -119.032
# 14  United States                 37.631                -119.032
# 15  United States                 37.631                -119.032
# 16  United States                 37.631                -119.032
# 17  United States                 33.197                -115.616
# 18  United States                 39.375                -119.720
# 19  United States                 39.375                -119.720
# 20  United States                 35.347                -111.678
# 21  United States                 19.421                -155.287
# 22  United States                 19.421                -155.287
# 23  United States                 19.421                -155.287
# 24  United States                 19.421                -155.287
# 25  United States                 19.421                -155.287
# 26  United States                 19.820                -155.470
#
#                                       Venue  Venue Latitude  Venue Longitude  \
# 0                             paradise view       46.853702      -121.758947
# 1                           Comcast Xfinity       46.853028      -121.762765
# 2                             Mount Rainier       46.851852      -121.757178
# 3                          Observation Peak       45.878133      -122.084091
# 4                              Pearly Gates       45.372446      -121.696507
# 5                                  Hogsback       45.370918      -121.698883
# 6                     Mount Bachelor Summit       43.979260      -121.688875
# 7              Cinnamon Butte Lookout Tower       43.241029      -122.109679
# 8                     Crater Lake Boat Tour       42.930000      -122.120000
# 9                                 Mt Shasta       41.409905      -122.194920
# 10                            la perla deli       41.409321      -122.195007
# 11                        Mt. Shasta Summit       41.410033      -122.195091
# 12                      Mount Lassen Summit       40.496048      -121.507416
# 13               Summit of Mammoth Mountain       37.630784      -119.033393
# 14                                 Eleven53       37.630740      -119.033245
# 15                   Top of The Sierra Cafe       37.630581      -119.033324
# 16                             Mammoth Peak       37.632080      -119.030630
# 17                          Red Hill Marina       33.195154      -115.612452
# 18                            Brians Shack.       39.374375      -119.718722
# 19                        Top Of Toll Road!       39.375149      -119.715849
# 20    Humphrey's Peak Summit, AZ High Point       35.346671      -111.678493
# 21                      Halema'uma'u Crater       19.419737      -155.287916
# 22                          Kilauea Lookout       19.423827      -155.284623
# 23                          Kilauea Volcano       19.419833      -155.288223
# 24  US Geological Benchmark Kilauea Caldera       19.419791      -155.288053
# 25                  Jaggar Museum Gift Shop       19.419978      -155.288511
# 26            Mauna Kea Observatory Complex       19.822871      -155.469632
#
#         Venue Category
# 0             Mountain
# 1     Business Service
# 2             Mountain
# 3                Trail
# 4                Trail
# 5                Trail
# 6             Mountain
# 7       Scenic Lookout
# 8        Boat or Ferry
# 9             Mountain
# 10  Mexican Restaurant
# 11            Mountain
# 12      Scenic Lookout
# 13          Ski Chalet
# 14           Cafeteria
# 15      Scenic Lookout
# 16            Mountain
# 17               Beach
# 18       Burrito Place
# 19      Scenic Lookout
# 20            Mountain
# 21             Volcano
# 22      Scenic Lookout
# 23             Volcano
# 24             Volcano
# 25       Historic Site
# 26            Mountain

# %%
print(volc_venues.groupby('Country').count())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-138-4c8f7b477588> in <module>
# ----> 1 print(volc_venues.groupby('Country').count())
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed)
#    5808             group_keys=group_keys,
#    5809             squeeze=squeeze,
# -> 5810             observed=observed,
#    5811         )
#    5812
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated)
#     407                 sort=sort,
#     408                 observed=observed,
# --> 409                 mutated=self.mutated,
#     410             )
#     411
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate)
#     596                 in_axis, name, level, gpr = False, None, gpr, None
#     597             else:
# --> 598                 raise KeyError(gpr)
#     599         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     600             # Add key to exclusions
#
# KeyError: 'Country'
